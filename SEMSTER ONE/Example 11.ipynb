# %% [markdown]
# HOW TO PLOT A SCATTER PLOT

# %%
import pandas as pd

# %%
df = pd.read_excel(r"Notebooks/dataset.xlsx")

# %%
print(df)
# Out:
#      S/N             student_names  Age Weight   Height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# 15   NaN          nakagga shanitah   21     50   175.26
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      S/N             student_names  Age Weight   Height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      S/N             student_names  Age Weight   Height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# ...

# %%
df.Age
# Out:
# 0     20
# 1     27
# 2     21
# 3     23
# 4     19
# 5     24
# 6     21
# 7     19
# 8     19
# 9     22
# 10    25
# 11    27
# 12    21
# 13    19
# 14    21
# 15    21
# 16    20
# 17    23
# 18    20
# 19    20
# 20    27
# 21    23
# 22    21
# 23    19
# 24    20
# 25    22
# 26    21
# 27    23
# 28    20
# 29    30
# 30    23
# 31    24
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt._get_pyplot_commands
# Out:
# <function matplotlib.pyplot._get_pyplot_commands() -> 'list[str]'>

# %%
Height = df["Height"]
weight = df["Weight"]
plt.plot("Height", "Weight", "o", alpha = 0.8)

# %%
plt.title("THE RELATIONSHIP BETWEEN WEIGHT AND HEIGHT IN COHORT 3")
plt.xlabel("Weight in KG")
plt.ylabel("Height in CM")
color = ["red"]

# %% [markdown]
# How to Quantifying or estimate the relationship

# %%
import matplotlib.pyplot as plt
 
#data
x = [0, 1, 1, 2, 2, 3]
y = [0, 1, 2, 1, 2, 3]
 
#color
color = ['red', 'blue', 'yellow', 'green', 'orange', 'cyan']
 
#scatter plot
plt.scatter(x, y, c = color)
 
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Height = df["Height"]
Weight = df["Weight"]
Height = Height.astype("str")

# %%
Height = df["Height"]
Weight = df["Weight"]
Height = Height.astype("str")
plt.plot("Height", "Weight")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Student\Desktop\ANGEL WITI COHORT 3\DATA SCIENCE AND MACHINE LEARNING\YEAR ONE\SEMSTER ONE\Example 11.ipynb Cell 16 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/Desktop/ANGEL%20WITI%20COHORT%203/DATA%20SCIENCE%20AND%20MACHINE%20LEARNING/YEAR%20ONE/SEMSTER%20ONE/Example%2011.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> Weight = df["Weight"]
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/Desktop/ANGEL%20WITI%20COHORT%203/DATA%20SCIENCE%20AND%20MACHINE%20LEARNING/YEAR%20ONE/SEMSTER%20ONE/Example%2011.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> Height = Height.astype("str")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Student/Desktop/ANGEL%20WITI%20COHORT%203/DATA%20SCIENCE%20AND%20MACHINE%20LEARNING/YEAR%20ONE/SEMSTER%20ONE/Example%2011.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> plt.plot("Height", "Weight")
#
# ...

# %% [markdown]
# PLOTTING A VIOLING PLOT

# %%
df = pd.read_excel(r"c:\Users\Student\Desktop\ANGEL WITI COHORT 3\DATA SCIENCE AND MACHINE LEARNING\YEAR ONE\SEMSTER ONE\Data\Angel.xlsx")

# %%
print(df)
# Out:
#      S/N             student_names  Age Weight   Height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# 15   NaN          nakagga shanitah   21     50   175.26
# ...

# %%
import seaborn as sns

# %%
sns.violinplot(x= "Age", y="Weight", data=df, inner=None)
# Out:
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.boxplot(x= "Age", y="Weight", color="Gold", data=df,)
# Out:
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.catplot(x="Age", y="Weight", color="purple", data=df)
# Out:
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# CORRELATION
# Choosing 3 variables

# %%
#Choosing 3 variables
columns = ["Age", "Weight", "Height"]

# %%
df = df[columns]

# %%
df.corr()
# Out:
#              Age    Weight    Height
# Age     1.000000  0.112649 -0.150338
# Weight  0.112649  1.000000 -0.023837
# Height -0.150338 -0.023837  1.000000
